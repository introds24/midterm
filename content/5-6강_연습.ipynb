# %% [markdown]
# # 5-6강 연습문제

# %% [markdown]
# - [서울시 열린데이터광장](https://data.seoul.go.kr/)은 서울시가 자체적으로 운영하거나 유관기관과의 협력으로 개방한 자료를 인터넷 홈페이지를 통해 누구나 활용할 수 있도록 개방한 데이터 포털입니다.
# - 이번 시간에는 *서울시 지하철호선별 역별 시간대별 승하차 인원 정보*의 2024년 월별 데이터를 활용하여 실습을 진행해보도록 하겠습니다.
# - 아래 코드셀을 실행시켜 데이터를 불러오세요.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# colab이나 개인 컴퓨터에서 실행할 때는 아래 두 줄을 주석 처리하고 실행하세요.
# import pyodide_http
# pyodide_http.patch_all()

url = 'https://raw.githubusercontent.com/ddangchani/DataScience23fall_data/main/data/seoul_metro_2024.csv'
df = pd.read_csv(url, index_col=False)
df.drop(columns=['작업일자'], inplace=True)

# %%
df.head()
# Out:
#       사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  05시-06시 하차인원  \
# 0  202409  1호선  동대문           471            19         10349          1754
# 1  202409  1호선  동묘앞           186             4          2586          1075
# 2  202409  1호선  서울역           511            16          7470          8314
# 3  202409  1호선   시청            65             3          1800          4431
# 4  202409  1호선  신설동           297            23          8641          2224
#
#    06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  23시-24시 승차인원  23시-24시 하차인원  \
# 0          8643          6493         15403  ...          6216          9191
# 1          3513          5007          8267  ...          1153          4498
# 2         12959         50508         39164  ...         26501         12945
# 3          3673         23517          7262  ...          9170          3687
# 4          9190          9017         20762  ...          3610          9071
#
# ...

# %% [markdown]
# ## 문제 1. 함수 작성하기 (1)
#
# 다음을 만족하는 함수 `get_station_name`을 작성하세요.
#
# - 함수 `get_station_name`은 입력변수로 역이름(**문자형**)을 받습니다.
# - 만일 해당 역이름이 `df` 데이터프레임의 `지하철역` 변수에 존재한다면, 해당 역이름을 그대로 반환(`return`)합니다.
# - 만일 입력변수가 불완전한 역 이름이라면, 해당 입력 문자열을 포함하는 역이름들을 아래 예시와 같이 안내문 + 리스트 형태로 출력(`print`)합니다.(안내문은 자유롭게 작성)
# - 입력 문자열을 포함하는 역이 없다면, "해당하는 역이 없습니다."라는 문구를 출력합니다.
# - pandas의 `Series` 객체의 `str.contains()` 메소드를 활용하세요.
#
#
# #### 예시 1
# ```python
# get_station_name('강남')
#
# # 출력결과
# 강남
# ```
# #### 예시 2
# ```python
# get_station_name('서울대')
#
# # 출력결과
# 다음의 역 이름을 확인하세요: ['서울대입구(관악구청)' '관악산(서울대)' '서울대벤처타운']
# ```
#
# #### 예시 3
# ```python
# get_station_name('서울대역')
#
# # 출력결과
# 해당하는 역이 없습니다.
# ```

# %%
def get_station_name(name):
    # 코드 작성
    ...

# %% [markdown]
# ## 문제 2. 함수 작성하기 (2)
#
# 다음을 만족하는 함수 `get_stations`를 작성하세요.
#
# - 함수 `get_stations`는 입력변수로 1에서 9사이의 지하철 노선 번호(**정수형**) 혹은 노선명(**문자형**)을 받습니다.
# - 각 노선별로 승하차인원의 합이 가장 많은 상위 5개 역을 출력합니다.
# - 출력 결과는 다음과 같이 리스트로 나와야 합니다.
#
# ```python
# # 예시
# print(get_stations(1))
#
# 결과 : ['서울역', '종각', '종로3가', '시청', '신도림']
#
# print(get_stations('2호선'))
#
# 결과 : ['강남', '잠실(송파구청)', '신림', '구로디지털단지', '신도림']
# ```

# %%
def get_stations(line):
    # 코드 작성
    ...

# %% [markdown]
# ## 문제 3
#
# 파이 차트를 활용하여 2024년 9월 지하철 이용객수의 **1호선부터 9호선까지** 점유율을 시각화하세요.
# - 1호선부터 9호선까지의 데이터는 그대로 두고, 나머지 호선의 데이터는 '기타'로 묶어 시각화하세요.
# - 점유율이 높은 순서대로 정렬하여 시각화하세요.
# - `matplotlib`의 `pie` 함수를 이용하세요.

# %% [markdown]
# ## 문제 4
# 다음을 설명을 바탕으로 시각화 함수 `plot_station()`을 작성하세요.
# - 인자로 역 이름을 받습니다.
# - 역의 이름이 적절하게 주어지지 않는 경우, 문제 1에서 작성한 함수 `get_station_name`를 이용해 적절한 이름을 입력받도록 안내합니다.
# - 해당 역의 시간대별 승하차 인원을 아래 출력 예시와 같이 바 그래프 형태로 출력합니다.
# - 시간대별 승하차 인원이란, 해당 시간대에 대해 해당 역의 모든 호선에 대한 (승차 + 하차) 인원을 합한 값입니다.
#
# 예시)
#
# ```python
# plot_station('서울역')
# ```
#
# 출력 예시)
#
# <img src='https://raw.githubusercontent.com/ddangchani/DataScience23fall_data/main/data/seoul_metro_2023.png' width=700px>

# %%
def plot_station(name):
    # 코드 작성
    ...
