# %% [markdown]
# # 2강. 파이썬 소개 - 연습문제
# - 이번 장에서는 ETL에 첨부한 `corona_age.csv` 파일을 사용해 데이터프레임에 대한 연습을 해보겠습니다.
# - 이 파일은 일자별로 코로나 바이러스 감염자의 연령대별 통계를 나타내는 파일입니다.

# %% [markdown]
# ## 1. 데이터 불러오기
# - csv 파일을 변수명 `corona_age`에 **데이터프레임** 자료형으로 저장하세요. 구글 드라이브를 마운트 해서, 본인에게 맞는 파일 경로를 설정하세요.
# (인코딩 오류가 발생할 경우, 인코딩 옵션을 추가해 올바르게 불러오세요.)

# %% [markdown]
# ## 2. 그룹화된 데이터의 추세 구하기
#
# 주어진 데이터를 활용하여, 요일별로 연령대별 확진자 수의 **평균**을 구하고 `.plot` 메소드를 활용하여 **20대 확진자의 요일별 추세**를 시각화 해보세요.
#
# > **힌트**
# > `.reset_index()` 메소드를 활용하세요

# %% [markdown]
# ## 3. 변수 정의하기
#
# 2021년 7월 21일부터 같은해 10월 3일까지 수도권에서는 가장 높은 거리두기 단계인 4단계 조치가 시행되었습니다. 또한, 2022년 4월 18일부터는 모든 사회적 거리두기 조치가 해제된 바 있습니다. 각각의 기간에 해당하는 데이터를 변수 `distancing`, `no_distancing`에 저장하세요.

# %% [markdown]
# ## Extra. 그래프 그리기
#
# 2번에서 정의한 두 데이터셋을 활용하여, 각각의 기간에 대해 **연령대별 평균 확진자 수의 분포**를 파악하고 싶습니다. 각 데이터프레임에 대해 **연령대별 평균 확진자 수의 분포**를 나타내는 **막대그래프**를 그려보세요.
#
# > 힌트 :`.plot` 메소드의 서브 메소드 `.bar()` 를 활용하세요.
# > `.plot.bar()` 로 사용 가능

# %% [markdown]
# ### 한글 폰트가 깨지면 아래 첫번째 코드셀을 실행하고 런타임을 다시 시작하세요.
# ### 이후 두번째 코드셀을 실행한 뒤, 그래프를 그리면 됩니다.

# %%
# 한글 폰트가 깨질 때 사용 - 실행이 완료되면 런타임 메뉴에서 다시 시작 선택
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
# 폰트 설치 > 런타임 다시시작 후 실행
import matplotlib.pyplot as plt
from matplotlib import rc

plt.rc('font', family='NanumBarunGothic') # colab 에서 한글 사용
